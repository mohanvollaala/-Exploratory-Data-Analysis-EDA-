# %%
import seaborn as sns

# %%
import pandas as pd
df = pd.read_csv("sales_and_customer_insights.csv")
df.head()
# Out:
#    Customer_ID   Product_ID Transaction_ID  Purchase_Frequency  \
# 0  CUST_9HOS83  PROD_IK97D1   TRANS_II1DZG                  17
# 1  CUST_AJU17N  PROD_UNN7KP   TRANS_9HJF7I                  10
# 2  CUST_11XNYF  PROD_0XEW2W   TRANS_OT96OM                   3
# 3  CUST_IGH8G3  PROD_3IIAJN   TRANS_45V00G                  12
# 4  CUST_OK6PUM  PROD_VMIWD2   TRANS_ZAK760                  18
#
#    Average_Order_Value Most_Frequent_Category  Time_Between_Purchases  \
# 0               172.57            Electronics                      45
# 1                64.89               Clothing                       6
# 2               120.38                 Sports                      23
# 3                70.34               Clothing                       5
# 4                42.39            Electronics                      10
#
#           Region  Churn_Probability  Lifetime_Value Launch_Date  \
# 0  South America               0.98          952.81  2020-03-14
# ...

# %%
sns.histplot(df['Purchase_Frequency'], kde=True)
# Out:
# <Axes: xlabel='Purchase_Frequency', ylabel='Count'>

# %%
sns.histplot(df['Average_Order_Value'], kde=True)
# Out:
# <Axes: xlabel='Average_Order_Value', ylabel='Count'>

# %%
sns.boxplot(x=df['Time_Between_Purchases'])
# Out:
# <Axes: xlabel='Time_Between_Purchases'>

# %%
# 4. Boxplot of Lifetime Value
sns.boxplot(x=df['Lifetime_Value'])
# Out:
# <Axes: xlabel='Lifetime_Value'>

# %%
sns.scatterplot(x='Average_Order_Value', y='Lifetime_Value', data=df)
# Out:
# <Axes: xlabel='Average_Order_Value', ylabel='Lifetime_Value'>

# %%
sns.scatterplot(x='Purchase_Frequency', y='Lifetime_Value', data=df)
# Out:
# <Axes: xlabel='Purchase_Frequency', ylabel='Lifetime_Value'>

# %%
sns.countplot(x='Most_Frequent_Category', data=df)
# Out:
# <Axes: xlabel='Most_Frequent_Category', ylabel='count'>

# %%
sns.countplot(x='Region', data=df)
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
sns.countplot(x='Season', data=df)
# Out:
# <Axes: xlabel='Season', ylabel='count'>

# %%
sns.pairplot(df.select_dtypes(include=['int64', 'float64']))

# %%
sns.kdeplot(df['Lifetime_Value'], shade=True)
# Out:
# /tmp/ipython-input-1445416974.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Lifetime_Value'], shade=True)
# <Axes: xlabel='Lifetime_Value', ylabel='Density'>

# %%
sns.kdeplot(df['Average_Order_Value'], shade=True)
# Out:
# /tmp/ipython-input-3482434647.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Average_Order_Value'], shade=True)
# <Axes: xlabel='Average_Order_Value', ylabel='Density'>

# %%
sns.boxplot(x='Region', y='Average_Order_Value', data=df)
# Out:
# <Axes: xlabel='Region', ylabel='Average_Order_Value'>

# %%
sns.boxplot(x='Region', y='Lifetime_Value', data=df)
# Out:
# <Axes: xlabel='Region', ylabel='Lifetime_Value'>

# %%
sns.violinplot(x='Season', y='Lifetime_Value', data=df)
# Out:
# <Axes: xlabel='Season', ylabel='Lifetime_Value'>

# %%
sns.barplot(x='Region', y='Average_Order_Value', data=df)
# Out:
# <Axes: xlabel='Region', ylabel='Average_Order_Value'>

# %%
sns.barplot(x='Region', y='Lifetime_Value', data=df)
# Out:
# <Axes: xlabel='Region', ylabel='Lifetime_Value'>

# %%
# 22. Lineplot for Purchase Frequency
sns.lineplot(x=df.index, y='Purchase_Frequency', data=df)
# Out:
# <Axes: xlabel='None', ylabel='Purchase_Frequency'>

# %%
# 23. Lineplot for Lifetime Value
sns.lineplot(x=df.index, y='Lifetime_Value', data=df)
# Out:
# <Axes: xlabel='None', ylabel='Lifetime_Value'>

# %%
sns.relplot(x='Average_Order_Value', y='Lifetime_Value', data=df)

# %%
sns.stripplot(x='Season', y='Lifetime_Value', data=df)
# Out:
# <Axes: xlabel='Season', ylabel='Lifetime_Value'>

# %%
sns.jointplot(x='Purchase_Frequency', y='Lifetime_Value', data=df, kind='hex')

# %%
sns.rugplot(x='Churn_Probability', data=df)
# Out:
# <Axes: xlabel='Churn_Probability'>
